# %%
def menu():
    print("""Gestão de listas de inteiros
(1) Introduza a lista à mão;
(2) Gerar lista com valores aleatórios;
(3) Maior elemento da lista;
(4) Bubble sort;
(0) Sair """)


def criarlistaM():
    n = int(input("Introduza o nº de elementos da lista: "))
    lista = []
    for i in range(n):
        elemento = int(input("Introduza o elemento" + str(i+1) + "i"))
        lista.append(elemento)
    return(lista)

def criarlistaA():
    import random
    n = int(input("Introduza o nº de elementos da lista: "))
    lista = []
    for i in range(n):
        elemento = random.randint(0, 100)
        lista.append(elemento)
    return(lista)


def maior(p):
    maior = p[0]
    for i in range(len(p)):
        if p[i] > maior:
            maior = p[i]
    return(maior)


def bubblesort():
    lista2 = criarlistaA()
    print(lista2)
    i = 0
    alteracao = 1
    while alteracao != 0:
        alteracao = 0
        for i in range(len(lista2)-1):
            if lista2[i] > lista2[i+1]:
                lista2[i], lista2[i+1] = lista2[i+1], lista2[i]
                i = i + 1
                alteracao = alteracao + 1
            else:
                i = i + 1
    return(lista2)



def fazer():
    opcao = "1"
    menu()
    while opcao != "0":
        opcao = input("Qual é a sua opção?")
        if opcao == "1":
            a = criarlistaM()
            print(a)
        elif opcao == "2":
            a = criarlistaA()
            print(a)
        elif opcao == "3":
            a = maior(p)
            print(a)
        elif opcao == "4":
            a = bubblesort()
            print(a)
        elif opcao == "0":
            print("Até à próxima...")
        else:
            print("Opção inválida")
print(fazer())
# Out:
# Gestão de listas de inteiros
# (1) Introduza a lista à mão;
# (2) Gerar lista com valores aleatórios;
# (3) Maior elemento da lista;
# (4) Bubble sort;
# (0) Sair
