# %%
def pensar():
    tentativa = 0
    print('Pense num número entre 0 e 100')
    encontrado = False
    b = 50
    c = 50
    while not encontrado:
        print(b)
        a = input('É maior, menor ou igual? ')
        if (a == "maior") :
            c = int(c // 2)
            b = b + c
            tentativa = tentativa + 1
            print(tentativa)
        elif (a == "menor"):
            c = int(c // 2)
            b = b - c
            tentativa = tentativa + 1
            print(tentativa)
        elif (a == "igual"):
            encontrado = True
    if encontrado:
        print(tentativa + 1)
        return(b)
    else:
        print('Número inválido')
print(pensar())
# Out:
# Pense num número entre 0 e 100
# 50
# É maior, menor ou igual? maior
# 1
# 75
# É maior, menor ou igual? menor
# 2
# 63
# É maior, menor ou igual? maior
# 3
# 69
# É maior, menor ou igual? menor
# 4
# 66
# É maior, menor ou igual? maior
# 5
# 67
# É maior, menor ou igual? igual
# 6
# 67
